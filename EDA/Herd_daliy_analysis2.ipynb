# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, LSTM, RepeatVector, TimeDistributed, Dense, Conv1D, MaxPooling1D, Flatten

# 加载数据并填充缺失值
file_path = 'C:/Users/13593/Desktop/dsp/Data Analysis/Merged_Sorted_Data_Herd_Daily.xlsx'
data = pd.read_excel(file_path, sheet_name='Sheet1')
data_filled = data.fillna(data.median(numeric_only=True))

# 将列名中的空格替换为下划线
data_filled = data_filled.rename(columns=lambda x: x.replace(' ', '_'))

# 选择数值型特征列
numeric_cols = data_filled.select_dtypes(include=['float64', 'int64']).columns
X = data_filled[numeric_cols].values  # 将数据转化为数组
print(numeric_cols)
# Out:
# Index(['Lac_Avg_Days', 'Weight', 'Rumination_Minutes', 'Total_feed',
#        'Average_cell_count', 'Day_production', 'Expected_Daily_Yield',
#        'Fat_indication', 'Fat/Protein_Ratio', 'Protein_indication',
#        'Concentrate_/_100_kg_Milk', 'Number_of_milkings',
#        'Total_Amount_of_Milk_Produced', 'Amount_of_Milk_Separated'],
#       dtype='object')

# %%
# 定义时间步长
timesteps = 10
n_features = X.shape[1]

# 将数据转换为LSTM输入格式 (样本数, 时间步数, 特征数)
X_sequence = []
for i in range(len(X) - timesteps):
    X_sequence.append(X[i:i + timesteps])

X_sequence = np.array(X_sequence)  # 3D数组 (样本数, 时间步长, 特征数)

# 将数据集划分为训练集和测试集
X_train, X_test = train_test_split(X_sequence, test_size=0.2, random_state=42)

# CNN + SAE 组合模型
input_seq = Input(shape=(timesteps, n_features))

# CNN 卷积层提取时间序列局部特征
x = Conv1D(filters=64, kernel_size=3, activation='relu')(input_seq)
x = MaxPooling1D(pool_size=2)(x)
x = Flatten()(x)

# 将 CNN 提取的特征通过 SAE 压缩为低维表示
encoded = Dense(64, activation='relu')(x)
encoded = RepeatVector(timesteps)(encoded)

# 解码器部分重构时间序列
decoded = LSTM(64, return_sequences=True, activation='relu')(encoded)
decoded = TimeDistributed(Dense(n_features))(decoded)

# 构建 CNN + SAE 模型
cnn_sae_model = Model(inputs=input_seq, outputs=decoded)
cnn_sae_model.compile(optimizer='adam', loss='mse')

# 训练 CNN + SAE 模型
cnn_sae_model.fit(X_train, X_train, epochs=50, batch_size=32, validation_split=0.2)

# 提取低维特征
encoder = Model(inputs=input_seq, outputs=encoded)
X_train_encoded = encoder.predict(X_train)
X_test_encoded = encoder.predict(X_test)

# 输出低维表示
print("Low-dimensional Representation from CNN + SAE (Train):", X_train_encoded.shape)
print("Low-dimensional Representation from CNN + SAE (Test):", X_test_encoded.shape)
# Out:
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 950471.0000 - val_loss: 535140.5625
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 362634.0625 - val_loss: 151980.3125
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 131236.8125 - val_loss: 83478.7500
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 86115.2109 - val_loss: 40620.5430
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 35112.8203 - val_loss: 25760.7480
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23158.3555 - val_loss: 18809.6387
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17233.5566 - val_loss: 15089.1709
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14358.9570 - val_loss: 13373.0781
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12836.1094 - val_loss: 12597.9248
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11963.9229 - val_loss: 12010.1689
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11371.3213 - val_loss: 10998.0088
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10350.1885 - val_loss: 10153.0215
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10109.5771 - val_loss: 9533.1445
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9499.4531 - val_loss: 8859.3848
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8860.1123 - val_loss: 8439.1504
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8235.4883 - val_loss: 8100.3350
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7903.1602 - val_loss: 7851.2041
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7502.6787 - val_loss: 7671.1895
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7707.2109 - val_loss: 7510.6743
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7346.6187 - val_loss: 7429.6436
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7252.1079 - val_loss: 7259.5562
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7117.5693 - val_loss: 7162.2090
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6928.1445 - val_loss: 7080.2075
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6896.9429 - val_loss: 6999.4609
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6846.7554 - val_loss: 6917.7349
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6779.6411 - val_loss: 6847.5513
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6614.4595 - val_loss: 6791.5444
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6637.6904 - val_loss: 6773.1641
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6692.6357 - val_loss: 6667.0527
# Epoch 30/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6759.7778 - val_loss: 6594.2070
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6586.2075 - val_loss: 6425.9116
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6417.8955 - val_loss: 6306.2827
# Epoch 33/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6330.6919 - val_loss: 6086.2476
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5980.4487 - val_loss: 5903.6675
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5756.0630 - val_loss: 5766.1021
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5837.5400 - val_loss: 5730.1533
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5734.9639 - val_loss: 5597.2197
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5446.5518 - val_loss: 5539.0269
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5312.2920 - val_loss: 5492.4473
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5324.8706 - val_loss: 5447.5552
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5383.3950 - val_loss: 5401.6685
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5095.9209 - val_loss: 5363.4497
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5280.2505 - val_loss: 5319.9263
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5334.9429 - val_loss: 5290.5889
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5346.8696 - val_loss: 5255.4194
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5068.7188 - val_loss: 5247.3057
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5264.2769 - val_loss: 5197.4492
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5099.8472 - val_loss: 5173.7803
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5060.5854 - val_loss: 5163.8032
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4932.3804 - val_loss: 5106.4321
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Low-dimensional Representation from CNN + SAE (Train): (2380, 10, 64)
# Low-dimensional Representation from CNN + SAE (Test): (595, 10, 64)

# %%
# 准备目标变量 (预测未来牛奶产量)，假设第0列是牛奶产量
y_sequence = []
for i in range(len(X) - timesteps):
    y_sequence.append(X[i + timesteps, 5])  # 假设第0列是牛奶产量

y_sequence = np.array(y_sequence)  # 目标变量
y_train, y_test = train_test_split(y_sequence, test_size=0.2, random_state=42)

# 将 CNN + SAE 提取的低维特征转换为适合 MLP 的格式
X_train_encoded_flat = X_train_encoded.reshape(X_train_encoded.shape[0], -1)  # 扁平化
X_test_encoded_flat = X_test_encoded.reshape(X_test_encoded.shape[0], -1)  # 扁平化

# 构建 MLP 模型
mlp_model = Sequential()
mlp_model.add(Dense(128, activation='relu', input_shape=(X_train_encoded_flat.shape[1],)))  # 输入层 + 隐藏层1
mlp_model.add(Dense(64, activation='relu'))  # 隐藏层2
mlp_model.add(Dense(32, activation='relu'))  # 隐藏层3
mlp_model.add(Dense(1))  # 输出层，回归任务预测一个值（未来的牛奶产量）

# 编译 MLP 模型
mlp_model.compile(optimizer='adam', loss='mse')

# 训练 MLP 模型
mlp_model.fit(X_train_encoded_flat, y_train, epochs=50, batch_size=32, validation_data=(X_test_encoded_flat, y_test))

# 使用 MLP 模型进行预测
y_pred = mlp_model.predict(X_test_encoded_flat)

# 查看测试集的预测结果
print("Predicted Milk Production:", y_pred[:5])
print("True Milk Production:", y_test[:5])
# Out:
# Epoch 1/50
# C:\Users\13593\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 44584.5469 - val_loss: 26.6172
# Epoch 2/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33.3589 - val_loss: 42.2378
# Epoch 3/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31.8766 - val_loss: 34.7798
# Epoch 4/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30.9711 - val_loss: 38.3751
# Epoch 5/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.8899 - val_loss: 24.0881
# Epoch 6/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 24.7809 - val_loss: 25.9887
# Epoch 7/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.3322 - val_loss: 19.2699
# Epoch 8/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.2178 - val_loss: 16.2717
# Epoch 9/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.5756 - val_loss: 23.0266
# Epoch 10/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.9942 - val_loss: 29.5577
# Epoch 11/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22.8333 - val_loss: 18.9713
# Epoch 12/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.9290 - val_loss: 41.0916
# Epoch 13/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.7082 - val_loss: 19.1593
# Epoch 14/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.7175 - val_loss: 22.3352
# Epoch 15/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 22.2526 - val_loss: 20.0778
# Epoch 16/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 23.5546 - val_loss: 148.5638
# Epoch 17/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 38.0153 - val_loss: 15.6039
# Epoch 18/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 43.1677 - val_loss: 80.3402
# Epoch 19/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 36.6459 - val_loss: 59.5643
# Epoch 20/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29.0482 - val_loss: 12.4640
# Epoch 21/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.7080 - val_loss: 13.4864
# Epoch 22/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.5583 - val_loss: 16.9532
# Epoch 23/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 35.7271 - val_loss: 58.4782
# Epoch 24/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.2290 - val_loss: 75.9236
# Epoch 25/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 68.4357 - val_loss: 12.4026
# Epoch 26/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 31.1123 - val_loss: 29.7900
# Epoch 27/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 35.3251 - val_loss: 22.2404
# Epoch 28/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33.5499 - val_loss: 14.3770
# Epoch 29/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 37.8890 - val_loss: 36.4525
# Epoch 30/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34.7954 - val_loss: 111.4087
# Epoch 31/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 46.3152 - val_loss: 11.8126
# Epoch 32/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 17.4047 - val_loss: 23.2137
# Epoch 33/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.0628 - val_loss: 13.3607
# Epoch 34/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 28.5916 - val_loss: 13.6894
# Epoch 35/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 32.9534 - val_loss: 63.5733
# Epoch 36/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.6237 - val_loss: 12.5584
# Epoch 37/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 17.1853 - val_loss: 22.9515
# Epoch 38/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 49.8846 - val_loss: 26.7773
# Epoch 39/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33.7149 - val_loss: 18.2961
# Epoch 40/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 89.6838 - val_loss: 31.2249
# Epoch 41/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.4033 - val_loss: 13.9541
# Epoch 42/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.3881 - val_loss: 10.3674
# Epoch 43/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.9334 - val_loss: 16.3220
# Epoch 44/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 24.4943 - val_loss: 34.2555
# Epoch 45/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34.8577 - val_loss: 14.9616
# Epoch 46/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33.0398 - val_loss: 10.9314
# Epoch 47/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.5769 - val_loss: 41.6058
# Epoch 48/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33.9891 - val_loss: 35.6959
# Epoch 49/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.6375 - val_loss: 31.8898
# Epoch 50/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 23.7786 - val_loss: 15.1089
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Predicted Milk Production: [[22.80283 ]
#  [20.981647]
#  [22.190647]
#  [26.796467]
#  [23.39774 ]]
# True Milk Production: [24.7 22.2 22.3 34.  25.8]

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Squared Error: 15.108878282454716
# Mean Absolute Error: 3.0585262032516867
